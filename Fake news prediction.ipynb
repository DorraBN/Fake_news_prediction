# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
df_fake=pd.read_csv("Fake.csv")

# %%
df_fake
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_true=pd.read_csv("True.csv")

# %%
df_true
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df_fake["class"]=0
df_true["class"]=1

# %%
df_fake.shape
# Out:
# (23481, 5)

# %%
df_true.shape
# Out:
# (21417, 5)

# %%
df_true
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
df_fake
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
data_fake_test=df_fake.tail(10)
data_fake_test
# Out:
#                                                    title  \
# 23471  Seven Iranians freed in the prisoner swap have...
# 23472                      #Hashtag Hell & The Fake Left
# 23473  Astroturfing: Journalist Reveals Brainwashing ...
# 23474          The New American Century: An Era of Fraud
# 23475  Hillary Clinton: ‘Israel First’ (and no peace ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23471  21st Century Wire says This week, the historic...  Middle-east
# 23472   By Dady Chery and Gilbert MercierAll writers ...  Middle-east
# 23473  Vic Bishop Waking TimesOur reality is carefull...  Middle-east
# ...

# %%
for i in range(23480,23470,-1):
    df_fake.drop([i],axis=0,inplace=True)

# %%
df_fake.shape
# Out:
# (23471, 5)

# %%
data_true_test=df_true.tail(10)
data_true_test
# Out:
#                                                    title  \
# 21407  Mata Pires, owner of embattled Brazil builder ...
# 21408  U.S., North Korea clash at U.N. forum over nuc...
# 21409  U.S., North Korea clash at U.N. arms forum on ...
# 21410  Headless torso could belong to submarine journ...
# 21411  North Korea shipments to Syria chemical arms a...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21407  SAO PAULO (Reuters) - Cesar Mata Pires, the ow...  worldnews
# 21408  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 21409  GENEVA (Reuters) - North Korea and the United ...  worldnews
# ...

# %%
for i in range(21416,21406,-1):
    df_true.drop([i] ,axis=0,inplace=True)

# %%
df_true.shape
# Out:
# (21407, 5)

# %%
data_merge=pd.concat([df_fake,df_true])

# %%
data_merge
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 21402  Exclusive: Trump's Afghan decision may increas...
# 21403  U.S. puts more pressure on Pakistan to help wi...
# 21404  Exclusive: U.S. to withhold up to $290 million...
# 21405  Trump talks tough on Pakistan's 'terrorist' ha...
# 21406  U.S., North Korea clash at U.N. forum over nuc...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# ...

# %%
data_merge.shape
# Out:
# (44878, 5)

# %%
data_merge.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  class
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
data_merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
data=data_merge.drop(['title','subject','date'],axis=1)

# %%
data
# Out:
#                                                     text  class
# 0      Donald Trump just couldn t wish all Americans ...      0
# 1      House Intelligence Committee Chairman Devin Nu...      0
# 2      On Friday, it was revealed that former Milwauk...      0
# 3      On Christmas day, Donald Trump announced that ...      0
# 4      Pope Francis used his annual Christmas Day mes...      0
# ...                                                  ...    ...
# 21402  ON BOARD A U.S. MILITARY AIRCRAFT (Reuters) - ...      1
# 21403  WASHINGTON (Reuters) - The United States sugge...      1
# 21404  WASHINGTON (Reuters) - The United States has d...      1
# 21405  ISLAMABAD (Reuters) - Outlining a new strategy...      1
# 21406  GENEVA (Reuters) - North Korea and the United ...      1
#
# [44878 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
data=data.sample(frac=1)

# %%
data
# Out:
#                                                     text  class
# 6075   Bobby Jindal s worst nightmare has come true: ...      0
# 12165  WASHINGTON (Reuters) - The United States on Fr...      1
# 9349   SPRINGFIELD, Ill. (Reuters) - Just days before...      1
# 9077   LONDON (Reuters) - Donald Trump told Britons o...      1
# 9231   Shame on Teen Vogue! Maxine Waters was a guest...      0
# ...                                                  ...    ...
# 17855  FRANKFURT (Reuters) - German authorities arres...      1
# 16509  Buckle up America Obama still has 6 months to ...      0
# 16450  (Reuters) - The world s fastest-growing humani...      1
# 711    Trumpcare failed in the most hilarious and dra...      0
# 4367   Everyone involved with Donald Trump s campaign...      0
#
# [44878 rows x 2 columns]

# %%
data.head(10)
# Out:
#                                                     text  class
# 6075   Bobby Jindal s worst nightmare has come true: ...      0
# 12165  WASHINGTON (Reuters) - The United States on Fr...      1
# 9349   SPRINGFIELD, Ill. (Reuters) - Just days before...      1
# 9077   LONDON (Reuters) - Donald Trump told Britons o...      1
# 9231   Shame on Teen Vogue! Maxine Waters was a guest...      0
# 4999   As Donald Trump s campaign continues to sink d...      0
# 23232  SARTRE 21st Century WireEvery day the world mo...      0
# 21226  MOSCOW (Reuters) - Russia is preparing to hold...      1
# 11876  RIO DE JANEIRO/SAO PAULO (Reuters) - Billionai...      1
# 20529  MONTEVIDEO (Reuters) - Uruguay s Vice Presiden...      1

# %%
data.reset_index(drop=True, inplace=True)


data.drop(['index'],axis=1,inplace=True)

# %%
data
# Out:
#        level_0                                               text  class
# 0            0  Bobby Jindal s worst nightmare has come true: ...      0
# 1            1  WASHINGTON (Reuters) - The United States on Fr...      1
# 2            2  SPRINGFIELD, Ill. (Reuters) - Just days before...      1
# 3            3  LONDON (Reuters) - Donald Trump told Britons o...      1
# 4            4  Shame on Teen Vogue! Maxine Waters was a guest...      0
# ...        ...                                                ...    ...
# 44873    44873  FRANKFURT (Reuters) - German authorities arres...      1
# 44874    44874  Buckle up America Obama still has 6 months to ...      0
# 44875    44875  (Reuters) - The world s fastest-growing humani...      1
# 44876    44876  Trumpcare failed in the most hilarious and dra...      0
# 44877    44877  Everyone involved with Donald Trump s campaign...      0
#
# [44878 rows x 3 columns]

# %%
data.columns
# Out:
# Index(['level_0', 'text', 'class'], dtype='object')

# %%
data.drop(['level_0'],axis=1,inplace=True)

# %%
data
# Out:
#                                                     text  class
# 0      Bobby Jindal s worst nightmare has come true: ...      0
# 1      WASHINGTON (Reuters) - The United States on Fr...      1
# 2      SPRINGFIELD, Ill. (Reuters) - Just days before...      1
# 3      LONDON (Reuters) - Donald Trump told Britons o...      1
# 4      Shame on Teen Vogue! Maxine Waters was a guest...      0
# ...                                                  ...    ...
# 44873  FRANKFURT (Reuters) - German authorities arres...      1
# 44874  Buckle up America Obama still has 6 months to ...      0
# 44875  (Reuters) - The world s fastest-growing humani...      1
# 44876  Trumpcare failed in the most hilarious and dra...      0
# 44877  Everyone involved with Donald Trump s campaign...      0
#
# [44878 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
def wordopt(text):
    text=text.lower()
    text=re.sub('\[.*?\]','',text)
    text=re.sub("\\W"," ",text)
    text=re.sub('http?://\S+/www\.\S+','',text)
    text=re.sub('<-*?>+','',text)
    text=re.sub('[%s]'%re.escape(string.punctuation),'',text)
    text=re.sub('\n','',text)
    text=re.sub('\w*\d\w*','',text)
    return text

# %%
data['text']=data['text'].apply(wordopt)

# %%
x=data['text']
y=data['class']

# %%
x
# Out:
# 0        bobby jindal s worst nightmare has come true  ...
# 1        washington  reuters    the united states on fr...
# 2        springfield  ill   reuters    just days before...
# 3        london  reuters    donald trump told britons o...
# 4        shame on teen vogue  maxine waters was a guest...
#                                ...
# 44873    frankfurt  reuters    german authorities arres...
# 44874    buckle up america obama still has  months to f...
# 44875     reuters    the world s fastest growing humani...
# 44876    trumpcare failed in the most hilarious and dra...
# 44877    everyone involved with donald trump s campaign...
# Name: text, Length: 44878, dtype: object

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 44873    1
# 44874    0
# 44875    1
# 44876    0
# 44877    0
# Name: class, Length: 44878, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
x_train.shape
# Out:
# (33658,)

# %%
x_test.shape
# Out:
# (11220,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <33658x95203 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6914611 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr=LR.predict(xv_test)

# %%
LR.score(xv_test,y_test)
# Out:
# 0.9875222816399287

# %%
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5755
#            1       0.99      0.99      0.99      5465
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %%
from sklearn.tree import DecisionTreeClassifier
DI =DecisionTreeClassifier()
DI.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_di = DI.predict(xv_test)

# %%
 DI.score(xv_test,y_test)
# Out:
# 0.9951871657754011

# %%
print(classification_report(y_test,pred_di))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5755
#            1       0.99      1.00      1.00      5465
#
#     accuracy                           1.00     11220
#    macro avg       1.00      1.00      1.00     11220
# weighted avg       1.00      1.00      1.00     11220

# %%
from sklearn.ensemble import GradientBoostingClassifier
Gb=GradientBoostingClassifier(random_state=0)
Gb.fit(xv_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
predict_gb=Gb.predict(xv_test)

# %%
Gb.score(xv_test,y_test)
# Out:
# 0.9958110516934047

# %%
print(classification_report(y_test,predict_gb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5755
#            1       0.99      1.00      1.00      5465
#
#     accuracy                           1.00     11220
#    macro avg       1.00      1.00      1.00     11220
# weighted avg       1.00      1.00      1.00     11220

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
RF.fit(xv_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rf=RF.predict(xv_test)

# %%
RF.score(xv_test,y_test)
# Out:
# 0.9867201426024955

# %%
print(classification_report(y_test,predict_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      5755
#            1       0.99      0.98      0.99      5465
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220
